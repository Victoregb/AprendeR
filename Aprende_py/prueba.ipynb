# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Esto es quizas muy venturoso pero me gusta trabajar con este tiempo de formato.

# %%
comp1 = 12
comp2 = 45

comp1+comp2
# Out:
# 57

# %%
y = np.arange(0,100)
x = np.arange(0,200, 2)

# %%
plt.plot(x,y)
