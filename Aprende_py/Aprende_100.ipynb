# %% [markdown]
# Estos son los ejercicios de Aprender Inteligencia Artificial, Combinatoria, Grafos y Algoritmos en Pytohn con 100 ejercicios practicos de la editorial Marcombo.

# %% [markdown]
# ## Ejercicio 1

# %%
b = 0
b += True
print('b =', b)

################################################################

a = True
b = 1 and True
c = 0 or True

print(a, b, c)

##############

comp1 = 1.7 + 3j
comp2 = 2.3 + 4.1j

print(comp1 + comp2)


####################

import decimal

b = decimal.Decimal("1234234.123412341234123412341234")
print(b)
# Out:
# b = 1
# True True True
# (4+7.1j)
# 1234234.123412341234123412341234

# %% [markdown]
# ## Ejercicio 2

# %%
print('Cadena vacia', str())
print('Repr en Cadena', str(['A', 'h']))
print('Copia en cadena', str('MJ'))

##############

s1 = 'Hola Don Pepito!!'
s2 = 'Hola \"Don José\"!!'


##############

s3 = ''' Esto es una de esas cadenas que contienen 'comillas' y que son interesantes '''
print(s3)

##############

print(s2)

##############

s4 = '\N{euro sign} \u20AC \U000020AC'

print(s4)
# Out:
# Cadena vacia
# Repr en Cadena ['A', 'h']
# Copia en cadena MJ
#  Esto es una de esas cadenas que contienen 'comillas' y que son interesantes
# Hola "Don José"!!
# € € €

# %% [markdown]
# ## Ejercicio 3

# %%
example_count = 10

print(example_count)

################################

#123 = 12

################################


Matriz = [[1,1,1], [0,0,0], [1,1,1]]

matriz = [2,2,2]
# Out:
# 10

# %% [markdown]
# ## Ejercicio 4

# %%
print(5/2)
print(2-5)


##############

print(5//2)

#######

print(5%2)

##############

print(5**2)

##############

print(divmod(5,2))


##############

print(round(3456.123425213, 2))
print(round(3456.123425213, -2))
print(round(3456.123425213, -3))
print(round(3456.123425213, -1))


##############

print(bin(500))
print(hex(500))
print(int(500))
print(oct(500))
# Out:
# 2.5
# -3
# 2
# 1
# 25
# (2, 1)
# 3456.12
# 3500.0
# 3000.0
# 3460.0
# 0b111110100
# 0x1f4
# 500
# 0o764

# %% [markdown]
# ## Ejercicio 5

# %%
t = tuple([1,2])
t
t = 1,2
t
t = (1,2)
t

##############

print(t[0])


##############

#t[0] = 42

##############



t.count(5)
t.index(1)

##############

t = (1, 'Hola', [43])

##############

t = 1, 
##############

t = (1, 'Hola', [43])
t[0:3]


'Hola' in t
# Out:
# 1
# True

# %% [markdown]
# ## Ejercicio 6

# %%
dicc = {}

dicc = dict()
##################

dicc = {'Nombre': 'Manuel', 'Edad':48}


print(dicc['Nombre'], dicc['Edad'])

dicc['Nombre'] = 'Sabrina'
dicc['Edad'] = 16

dicc

del(dicc['Nombre'])

dicc.clear()

dicc

dicc['Nombre'] = 'Sabrina'
dicc['Edad'] = 16

dicc.items()

for i in dicc:
    print(i, dicc[i])
# Out:
# Manuel 48
# Nombre Sabrina
# Edad 16

# %% [markdown]
# ## Ejercicio 7

# %%
l = [1, 2, 3]


#####

print(5 in l)
print(5 not in l)
print(max(l))
print(min(l))
print(len(l))

h = [3,4,5,6]

print(l+h)
print(l*5)
print(l)
print(l[:2])
print(l[:-1])
print(l[:-2])
print(l[1])
# Out:
# False
# True
# 3
# 1
# 3
# [1, 2, 3, 3, 4, 5, 6]
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]
# [1, 2, 3]
# [1, 2]
# [1, 2]
# [1]

# %% [markdown]
# ## Ejercicion 8

# %%
hora = ['9:00', '12:00', '21:00']
comer = ['desayunar', 'almozar', 'cenar']

for i in [0,1,2]:
    print('Son las {0} y es el momento de {1}'.format(hora[i], comer[i]))

####################

s = "{0} {1} {2}"
s = s.format('Esto', 'es', 'sencillo')
print(s)

####################

print('{quien} fue al {lugar} {cuando}'.format(quien='Ana', lugar='parque', cuando='ayer'))

####################

comer = ['desayunar', 'almozar', 'cenar']
s = 'Primero a {0[0]}, despues a {0[1]} y antes de dormir vamos a {1[2]}'.format(comer, hora)
print(s)

####################

d = dict(profesion='bombero', edad=45)
s = 'Manuel es {0[profesion]} y tiene {0[edad]}'.format(d)
print(s)

####################

a = 2
b = 3

print("Arroz: {a}, Tomates {b}".format(**locals()))
# Out:
# Son las 9:00 y es el momento de desayunar
# Son las 12:00 y es el momento de almozar
# Son las 21:00 y es el momento de cenar
# Esto es sencillo
# Ana fue al parque ayer
# Primero a desayunar, despues a almozar y antes de dormir vamos a 21:00
# Manuel es bombero y tiene 45
# Arroz: 2, Tomates 3

# %% [markdown]
# ## Ejercicio 9

# %%
def f(a, b = 2):
    return a + b

f(4,5)
####################

def f(a, b={}):
    b[0]=a
    return b
print(f(4))
print(f(5))

####################

def sumaPonderada(*elems):
    result = 0
    for e in elems:
        result += e[0] * e[1]
    return result

print(sumaPonderada((1,2), (2,3), (3,4)))

####################

def obtenerCasas(**casas):
    for c in casas:
        s = int(c.split('_')[1])
        if s>0:
            print(casas[c])
obtenerCasas(c_1='Casa Mex', c_2='Casa EEUU', c_3='Casa Cuba')
# Out:
# {0: 4}
# {0: 5}
# 20
# Casa Mex
# Casa EEUU
# Casa Cuba

# %% [markdown]
# ## Ejercicio 10

# %%
def selector(a):
    if a > 2 and a < 4:
        print('A > 2 && A < 4')
    elif a > 0 and a <= 5:
        pass
    elif a < 0:
        print('A < 0')
    else:
        print('NADA')

selector(4)
selector(3)
selector(13)
selector(-4)


def cond(a, b):
    return True if a > b else False

print(cond(3,2))

print(cond(2,3))
# Out:
# A > 2 && A < 4
# NADA
# A < 0
# True
# False

# %% [markdown]
# ## Ejercicio 11

# %%
i=1
while i <= 5:
    print('Iteracion', i)
    i +=1

print('\n\n')

for i in range(1,6):
    print(i)

print('\n\n')
for i in range(1,6):
    if i is 1:
        continue
    print(i)
    if i is 3:
        break
# Out:
# Iteracion 1
# Iteracion 2
# Iteracion 3
# Iteracion 4
# Iteracion 5
#
#
#
# 1
# 2
# 3
# 4
# 5
#
#
#
# 2
# 3

# %% [markdown]
# ## Ejercicio 12

# %%
# Ejercicio de ordenamiento burbuja

# %% [markdown]
# ## Ejercicio 13
